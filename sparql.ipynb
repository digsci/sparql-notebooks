# %% [markdown]
# Demonstrates the SPARQL Jupyter kernel found at https://github.com/paulovn/sparql-kernel

# %% [markdown]
# Set the SPARQL endpoint using '%endpoint <url>'

# %%
%endpoint http://localhost:8890/sparql
# Out:
# Endpoint set to: http://localhost:8890/sparql

# %% [markdown]
# Discover all monitoring stations in "Lune and Wyre" catchment area along with their latest readings (of any type)

# %%
PREFIX rt:<http://environment.data.gov.uk/flood-monitoring/def/core/>
PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
PREFIX geo:<http://www.w3.org/2003/01/geo/wgs84_pos#>

SELECT ?label ?town ?lon ?lat ?s ?measures ?latestReading ?latestValue
FROM <http://environment.data.gov.uk/flood-monitoring/id/stations.rdf>
FROM <http://environment.data.gov.uk/flood-monitoring/id/measures.rdf>
FROM <http://environment.data.gov.uk/flood-monitoring/data/readings.rdf>
WHERE 
{
  ?s rt:town ?town ;
     geo:long ?lon ;
     geo:lat ?lat ;
     rt:catchmentName "Lune and Wyre" ; 
     rdfs:label ?label ;
     rt:measures ?measures . 
     ?measures rt:latestReading ?latestReading . 
     ?latestReading rt:value ?latestValue .
}
# Out:
# {'head': {'link': [],
#           'vars': ['label',
#                    'town',
#                    'lon',
#                    'lat',
#                    's',
#                    'measures',
#                    'latestReading',
#                    'latestValue']},
#  'results': {'bindings': [{'label': {'type': 'literal',
#                                      'value': 'Abbeystead Reservoir'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.978695'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720101-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.069'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.677098'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720101-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720101'},
#                            'town': {'type': 'literal', 'value': 'Abbeystead'}},
#                           {'label': {'type': 'literal', 'value': 'Garstang'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.896103'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720107-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.253'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.779699'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720107-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720107'},
#                            'town': {'type': 'literal', 'value': 'Garstang'}},
#                           {'label': {'type': 'literal', 'value': 'Six Arches'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.937868'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720120-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.321'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.770317'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720120-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720120'},
#                            'town': {'type': 'literal', 'value': 'Scorton'}},
#                           {'label': {'type': 'literal', 'value': 'A6 Bridge'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.858854'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720215-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.198'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.743276'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720215-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720215'},
#                            'town': {'type': 'literal', 'value': 'Bilsborrow'}},
#                           {'label': {'type': 'literal', 'value': 'Roe Bridge'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.862594'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720248-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.205'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.790936'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720248-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720248'},
#                            'town': {'type': 'literal', 'value': 'Myerscough'}},
#                           {'label': {'type': 'literal', 'value': 'St Michaels'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.863761'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720517-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.312'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.817872'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720517-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720517'},
#                            'town': {'type': 'literal',
#                                     'value': "St Michael's On Wyre"}},
#                           {'label': {'type': 'literal', 'value': 'Catterall'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.866048'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720535-level-logged-i-15_min-mASD/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.544'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.811986'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720535-level-logged-i-15_min-mASD'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720535'},
#                            'town': {'type': 'literal',
#                                     'value': "St Michael's On Wyre"}},
#                           {'label': {'type': 'literal', 'value': 'Catterall'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.866048'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720535-level-stage-i-15_min-mASD/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '-1.927'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.811986'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720535-level-stage-i-15_min-mASD'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720535'},
#                            'town': {'type': 'literal',
#                                     'value': "St Michael's On Wyre"}},
#                           {'label': {'type': 'literal', 'value': 'Fleetwood'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.926518'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720763-level-stage-i-15_min-mASD/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '1.142'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-3.00474'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720763-level-stage-i-15_min-mASD'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720763'},
#                            'town': {'type': 'literal', 'value': 'Fleetwood'}},
#                           {'label': {'type': 'literal', 'value': 'Fleetwood'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.926518'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720763-wind-direction-Mean-15_min-deg/2017-04-21T04-30-30Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '297.0'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-3.00474'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720763-wind-direction-Mean-15_min-deg'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720763'},
#                            'town': {'type': 'literal', 'value': 'Fleetwood'}},
#                           {'label': {'type': 'literal', 'value': 'Fleetwood'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.926518'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720763-wind-speed-Mean-15_min-m_s/2017-04-21T04-30-30Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '2.398'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-3.00474'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720763-wind-speed-Mean-15_min-m_s'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720763'},
#                            'town': {'type': 'literal', 'value': 'Fleetwood'}},
#                           {'label': {'type': 'literal',
#                                      'value': 'Preesall Pumping Station, '
#                                               'Cockers Dyke'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.938698'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/720780-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '1.002'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.955067'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/720780-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720780'},
#                            'town': {'type': 'literal',
#                                     'value': 'Pilling Lane'}},
#                           {'label': {'type': 'literal',
#                                      'value': 'Lunes Bridge'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.420034'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/722242-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.376'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.599286'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/722242-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/722242'},
#                            'town': {'type': 'literal', 'value': 'Tebay'}},
#                           {'label': {'type': 'literal', 'value': 'Killington'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.310113'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/722421-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.256'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.582471'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/722421-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/722421'},
#                            'town': {'type': 'literal', 'value': 'Killington'}},
#                           {'label': {'type': 'literal', 'value': 'Brigflats'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.314107'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/723423-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.531'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.555012'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/723423-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/723423'},
#                            'town': {'type': 'literal', 'value': 'Sedbergh'}},
#                           {'label': {'type': 'literal',
#                                      'value': 'Bentham Bridge'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.113463'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/724320-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.466'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.510184'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/724320-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724320'},
#                            'town': {'type': 'literal',
#                                     'value': 'High Bentham'}},
#                           {'label': {'type': 'literal', 'value': 'Low Bentham'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.118746'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/724323-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.593'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.53947'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/724323-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724323'},
#                            'town': {'type': 'literal', 'value': 'Low Bentham'}},
#                           {'label': {'type': 'literal', 'value': 'Wennington'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.125115'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/724326-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.226'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.589971'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/724326-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724326'},
#                            'town': {'type': 'literal', 'value': 'Wennington'}},
#                           {'label': {'type': 'literal', 'value': 'Wray'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.105893'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/724427-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.192'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.605757'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/724427-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724427'},
#                            'town': {'type': 'literal', 'value': 'Wray'}},
#                           {'label': {'type': 'literal', 'value': 'Hornby'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.109696'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/724528-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.287'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.63518'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/724528-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724528'},
#                            'town': {'type': 'literal', 'value': 'Hornby'}},
#                           {'label': {'type': 'literal', 'value': 'Caton'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.081344'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/724629-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.402'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.722026'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/724629-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724629'},
#                            'town': {'type': 'literal', 'value': 'Caton'}},
#                           {'label': {'type': 'literal', 'value': 'Burrow Beck'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.039446'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/724700-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.287'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.780563'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/724700-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724700'},
#                            'town': {'type': 'literal', 'value': 'Lancaster'}},
#                           {'label': {'type': 'literal',
#                                      'value': 'Lancaster Quay'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.051851'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/724735-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '1.51'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.822021'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/724735-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724735'},
#                            'town': {'type': 'literal', 'value': 'Lancaster'}},
#                           {'label': {'type': 'literal', 'value': 'Galgate'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.991743'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/724836-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.169'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.792162'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/724836-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724836'},
#                            'town': {'type': 'literal', 'value': 'Galgate'}},
#                           {'label': {'type': 'literal',
#                                      'value': 'Pilling, Broadfleet'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.932062'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/725139-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.629'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.905476'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/725139-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/725139'},
#                            'town': {'type': 'literal', 'value': 'Pilling'}},
#                           {'label': {'type': 'literal',
#                                      'value': 'High River Keer'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.140607'},
#                            'latestReading': {'type': 'uri',
#                                              'value': 'http://environment.data.gov.uk/flood-monitoring/data/readings/733020-level-stage-i-15_min-m/2017-04-21T04-30-00Z'},
#                            'latestValue': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                            'type': 'typed-literal',
#                                            'value': '0.158'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.731323'},
#                            'measures': {'type': 'uri',
#                                         'value': 'http://environment.data.gov.uk/flood-monitoring/id/measures/733020-level-stage-i-15_min-m'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/733020'},
#                            'town': {'type': 'literal', 'value': 'Capernwray'}}],
#              'distinct': False,
#              'ordered': True}}

# %% [markdown]
# Find the "Morecambe North" and "Morecambe South" Bathing Water Quality (BWQ) stations using the Environment Agency BWQ endpoint

# %%
%endpoint http://environment.data.gov.uk/sparql/bwq/query
# Out:
# Endpoint set to: http://environment.data.gov.uk/sparql/bwq/query

# %%
PREFIX bw: <http://environment.data.gov.uk/def/bathing-water/>
PREFIX bwq: <http://environment.data.gov.uk/def/bathing-water-quality/>
PREFIX ef-sp: <http://location.data.gov.uk/def/ef/SamplingPoint/>
PREFIX interval: <http://reference.data.gov.uk/def/intervals/>
PREFIX stats: <http://statistics.data.gov.uk/def/administrative-geography/>
PREFIX sr: <http://data.ordnancesurvey.co.uk/ontology/spatialrelations/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?s
WHERE 
{
  { ?s rdfs:label "Morecambe North"@en . }
  UNION
  { ?s rdfs:label "Morecambe South"@en . }
}
# Out:
# {'head': {'vars': ['s']},
#  'results': {'bindings': [{'s': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/id/bathing-water/ukd4305-43550'}},
#                           {'s': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/id/bathing-water/ukd4305-43260'}}]}}

# %% [markdown]
# Discover any BWQ stations with Morecambe in their name

# %%
%endpoint http://environment.data.gov.uk/sparql/bwq/query
# Out:
# Endpoint set to: http://environment.data.gov.uk/sparql/bwq/query

# %%
prefix bw: <http://environment.data.gov.uk/def/bathing-water/>
prefix bwq: <http://environment.data.gov.uk/def/bathing-water-quality/>
prefix ef-sp: <http://location.data.gov.uk/def/ef/SamplingPoint/>
prefix interval: <http://reference.data.gov.uk/def/intervals/>
prefix stats: <http://statistics.data.gov.uk/def/administrative-geography/>
prefix sr: <http://data.ordnancesurvey.co.uk/ontology/spatialrelations/>
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix owl: <http://www.w3.org/2002/07/owl#>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>
prefix geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>

select ?label ?lat ?lon
where
{ ?o ef-sp:samplingPoint ?sp .
  ?sp geo:lat ?lat .
  ?sp geo:long ?lon .
  { select ?o ?label
    where {
      ?o a bw:BathingWater ;
         rdfs:label ?label .
      filter regex(?label, "morecambe", "i")
    }
  }
}
# Out:
# {'head': {'vars': ['label', 'lat', 'lon']},
#  'results': {'bindings': [{'label': {'type': 'literal',
#                                      'value': 'Morecambe South',
#                                      'xml:lang': 'en'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.0728262826181'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.87646762415598'}},
#                           {'label': {'type': 'literal',
#                                      'value': 'Morecambe North',
#                                      'xml:lang': 'en'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.0774517391814'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.86074604518309'}}]}}

# %% [markdown]
# Discover DBpedia information about any resources within 20km of New York City

# %%
%endpoint http://dbpedia.org/sparql
# Out:
# Endpoint set to: http://dbpedia.org/sparql

# %%
SELECT DISTINCT ?location 
WHERE 
  { 
    <http://dbpedia.org/resource/New_York_City> geo:geometry ?sourcegeo . 
    ?resource geo:geometry ?location ; 
                                 rdfs:label ?label . 
    FILTER( bif:st_intersects( ?location, ?sourcegeo, 20 ) ) . 
    FILTER( lang( ?label ) = "en" ) 
  }
# Out:
# _:ub17bL3533C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL3534C19 .
# _:ub17bL385C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL386C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL9533C18 .
# _:ub17bL7867C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL7868C19 .
# _:ub17bL7565C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL7566C19 .
# _:ub17bL2079C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL2080C19 .
# _:ub17bL8504C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.820556640625 40.722499847412)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL3162C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.915428161621 40.837547302246)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL9536C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1282C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL7826C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL736C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.907699584961 40.627101898193)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL2258C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL6481C18 .
# _:ub17bL4559C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL4560C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL4759C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3099C18 .
# _:ub17bL6098C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL531C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL532C19 .
# _:ub17bL1109C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1110C19 .
# _:ub17bL7680C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.883827209473 40.862148284912)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL10850C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.881896972656 40.867099761963)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL981C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL505C18 .
# _:ub17bL9447C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9448C19 .
# _:ub17bL8555C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL8556C19 .
# _:ub17bL170C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.996322631836 40.753395080566)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL3541C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL3542C19 .
# _:ub17bL3043C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL3044C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL1739C18 .
# _:ub17bL10003C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL10004C19 .
# _:ub17bL7517C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL7518C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3685C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL751C18 .
# _:ub17bL3451C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL3452C19 .
# _:ub17bL4262C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.935279846191 40.769443511963)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL6874C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3491C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL6453C18 .
# _:ub17bL7132C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.97900390625 40.688556671143)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL1743C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1744C19 .
# _:ub17bL1302C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL2044C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.930641174316 40.851261138916)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL6486C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL5920C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL3976C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL10134C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL8036C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.986557006836 40.741554260254)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL9531C18 .
# _:ub17bL3492C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL4996C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL2727C18 .
# _:ub17bL2383C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL2384C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL425C18 .
# _:ub17bL5569C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL5570C19 .
# _:ub17bL9430C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL3393C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL3394C19 .
# _:ub17bL4252C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.961486816406 40.779602050781)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL2486C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL7302C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL3228C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL8401C18 .
# _:ub17bL262C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.99055480957 40.7497215271)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL4374C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.966110229492 40.771667480469)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL2602C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.983558654785 40.718650817871)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL9966C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.168891906738 40.741943359375)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL757C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL758C19 .
# _:ub17bL542C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL9949C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9950C19 .
# _:ub17bL4749C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL4750C19 .
# _:ub17bL1410C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL6510C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.997222900391 40.729442596436)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL1482C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1504C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.987686157227 40.772369384766)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL4292C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.010398864746 40.707401275635)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL9796C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.811012268066 40.725341796875)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL10712C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL3900C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL4148C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL5956C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL4603C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL4604C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3793C18 .
# _:ub17bL6348C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL8024C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.009658813477 40.71265411377)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL10470C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1889C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1890C19 .
# _:ub17bL1457C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1458C19 .
# _:ub17bL1848C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.941886901855 40.618541717529)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL2393C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL8371C18 .
# _:ub17bL6622C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73
"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL9543C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9544C19 .
# _:ub17bL9972C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.104446411133 40.81555557251)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL1162C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL9062C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1084C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL3502C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL8273C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL8274C19 .
# _:ub17bL8902C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.830787658691 40.714149475098)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL4133C18 .
# _:ub17bL3988C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL530C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL6838C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL4413C18 .
# _:ub17bL8362C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL5352C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.999000549316 40.708000183105)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL5226C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.127418518066 40.86275100708)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL2840C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL3538C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.936668395996 40.825832366943)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL4082C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.131401062012 40.831699371338)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL1583C18 .
# _:ub17bL726C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.985000610352 40.873889923096)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL9308C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL6212C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL9555C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9556C19 .
# _:ub17bL9335C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9336C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL2197C18 .
# _:ub17bL3050C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL788C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL2281C18 .
# _:ub17bL8159C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL8160C19 .
# _:ub17bL6886C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL3727C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL3728C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL1073C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL4981C18 .
# _:ub17bL5162C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL7352C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.999443054199 40.721942901611)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3873C18 .
# _:ub17bL9169C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9170C19 .
# _:ub17bL9351C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9352C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL9745C18 .
# _:ub17bL1653C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1654C19 .
# _:ub17bL4980C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.989700317383 40.727802276611)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL242C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1496C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.004081726074 40.754749298096)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL10785C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL10786C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL4805C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL6303C18 .
# _:ub17bL7726C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL6313C18 .
# _:ub17bL9889C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9890C19 .
# _:ub17bL4334C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL7454C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL7998C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.991836547852 40.742084503174)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL3611C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL3612C19 .
# _:ub17bL8768C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL4745C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL4746C19 .
# _:ub17bL5311C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL5312C19 .
# _:ub17bL8196C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1822C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.078796386719 40.780899047852)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL994C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL4298C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.965026855469 40.773979187012)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL7830C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.996910095215 40.737373352051)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL10704C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.97297668457 40.755550384521)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL1227C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1228C19 .
# _:ub17bL10680C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL1917C18 .
# _:ub17bL1216C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1762C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL5790C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL3250C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.940414428711 40.828609466553)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL1353C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1354C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL9699C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL7883C18 .
# _:ub17bL3535C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL3536C19 .
# _:ub17bL1853C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1854C19 .
# _:ub17bL2252C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.989036560059 40.722900390625)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL7881C18 .
# _:ub17bL10900C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.860557556152 40.860000610352)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL3408C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.005142211914 40.728385925293)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL10399C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL5271C18 .
# _:ub17bL2772C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.040832519531 40.726387023926)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL1909C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1910C19 .
# _:ub17bL9110C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL2045C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL2046C19 .
# _:ub17bL3672C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL4701C18 .
# _:ub17bL8650C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL4134C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL5808C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.958000183105 40.783699035645)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL4327C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL4328C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL677C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL7075C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL9713C18 .
# _:ub17bL4848C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL4804C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.952697753906 40.771373748779)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL5392C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.961898803711 40.775398254395)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL8135C18 .
# _:ub17bL5841C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL5842C19 .
# _:ub17bL1021C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1022C19 .
# _:ub17bL3874C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.973304748535 40.762950897217)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL4417C18 .
# _:ub17bL8201C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL8202C19 .
# _:ub17bL2240C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.054000854492 40.737998962402)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL10885C18 .
# _:ub17bL9802C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.962219238281 40.812721252441)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3575C18 .
# _:ub17bL12C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL6785C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL6786C19 .
# _:ub17bL6071C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL6072C19 .
# _:ub17bL8262C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.004165649414 40.711112976074)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL4925C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL4926C19 .
# _:ub17bL5678C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.969863891602 40.749443054199)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL8575C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL8576C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL5981C18 .
# _:ub17bL2540C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.990280151367 40.679721832275)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL8719C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL8720C19 .
# _:ub17bL8055C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL8056C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL9385C18 .
# _:ub17bL2832C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.974723815918 40.755516052246)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL6193C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL6194C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL725C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL2823C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL10115C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL5917C18 .
# _:ub17bL9612C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.880279541016 40.720275878906)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL5364C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.106323242188 40.853084564209)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL10147C18 .
# ...
# _:ub17bL6774C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.000144958496 40.73002243042)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL3398C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.991432189941 40.729862213135)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL8804C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL7603C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL7604C19 .
# _:ub17bL5804C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL10368C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL8652C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.959991455078 40.809448242188)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL8354C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL7862C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL2453C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL10781C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL6419C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL1815C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL851C18 .
# _:ub17bL9832C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.991340637207 40.735530853271)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL3718C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.981994628906 40.612884521484)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL980C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.074913024902 40.814208984375)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL1609C18 .
# _:ub17bL6466C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL9863C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9864C19 .
# _:ub17bL7129C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL7130C19 .
# _:ub17bL1074C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.048599243164 40.715099334717)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL8715C18 .
# _:ub17bL4920C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL6059C18 .
# _:ub17bL2374C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.923187255859 40.827499389648)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3941C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL2205C18 .
# _:ub17bL10538C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1202C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL2789C18 .
# _:ub17bL10857C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL10858C19 .
# _:ub17bL7991C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL7992C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL7317C18 .
# _:ub17bL7918C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.983612060547 40.771945953369)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL10002C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.979179382324 40.574329376221)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL2841C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL2842C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3533C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL405C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL8183C18 .
# _:ub17bL2436C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.005279541016 40.726833343506)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL4172C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1330C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.013198852539 40.712898254395)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL2253C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL2254C19 .
# _:ub17bL6333C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL6334C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL8891C18 .
# _:ub17bL3316C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL9162C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1024C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.094825744629 40.617404937744)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL8127C18 .
# _:ub17bL6648C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL7233C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL7234C19 .
# _:ub17bL7846C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL6591C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL6592C19 .
# _:ub17bL9312C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL9700C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL7924C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL4624C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL908C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3111C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL7543C18 .
# _:ub17bL5806C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.956390380859 40.769165039062)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL8377C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL8378C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL6709C18 .
# _:ub17bL8830C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3553C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3923C18 .
# _:ub17bL7650C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL2819C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL2820C19 .
# _:ub17bL7902C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL1021C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL10905C18 .
# _:ub17bL5210C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1140C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.979873657227 40.82056427002)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL7572C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.009002685547 40.701301574707)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL5207C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL5208C19 .
# _:ub17bL4816C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.002113342285 40.608665466309)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL5045C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL1647C18 .
# _:ub17bL6430C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL1351C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1352C19 .
# _:ub17bL5856C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.006057739258 40.704700469971)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL6553C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL6554C19 .
# _:ub17bL10859C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL10860C19 .
# _:ub17bL4715C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL4716C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL133C18 .
# _:ub17bL4984C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.974586486816 40.787975311279)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL10693C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL10694C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL7137C18 .
# _:ub17bL8493C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL8494C19 .
# _:ub17bL1290C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.070999145508 40.714000701904)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL3015C18 .
# _:ub17bL5586C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.950866699219 40.663059234619)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL8150C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL2994C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.964469909668 40.644626617432)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL9666C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.980278015137 40.747501373291)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL5838C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.979179382324 40.574310302734)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL9533C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9534C19 .
# _:ub17bL4146C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL10201C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL10202C19 .
# _:ub17bL7337C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL7338C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL10621C18 .
# _:ub17bL7122C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL8507C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL8508C19 .
# _:ub17bL10276C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.160285949707 40.817890167236)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL2668C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL3506C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL2963C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL2964C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL7295C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL9593C18 .
# _:ub17bL4590C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.173400878906 40.837600708008)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL8612C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL10185C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL10186C19 .
# _:ub17bL4983C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL4984C19 .
# _:ub17bL8464C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL10258C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL4117C18 .
# _:ub17bL1070C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.081871032715 40.788078308105)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL7609C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL7610C19 .
# _:ub17bL6995C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL6996C19 .
# _:ub17bL5704C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL10222C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-74.17749786377 40.755554199219)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL9000C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.822799682617 40.728073120117)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL5848C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.959678649902 40.782428741455)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL5165C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL5166C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL7579C18 .
# _:ub17bL7847C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL7848C19 .
# _:ub17bL3432C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.990447998047 40.73189163208)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL1343C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1344C19 .
# _:ub17bL10706C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.968399047852 40.804298400879)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL3799C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL3800C19 .
# _:ub17bL7886C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL8150C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.992118835449 40.742771148682)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL7378C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.996398925781 40.74430847168)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL7582C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL801C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL802C19 .
# _:ub17bL1916C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.89412689209 40.664722442627)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:ub17bL9615C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL9616C19 .
# _:ub17bL1930C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL885C18 .
# _:ub17bL3108C19 <http://www.w3.org/2005/sparql-results#value> "POINT(-73.974822998047 40.7551612854)"^^<http://www.openlinksw.com/schemas/virtrdf#Geometry> .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL4469C18 .
# _:ub17bL7334C19 <http://www.w3.org/2005/sparql-results#variable> "location" .
# _:ub17bL2749C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL2750C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL9931C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL6787C18 .
# _:ub17bL1981C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1982C19 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL6195C18 .
# _:f07e0ac84e21347bbb532b0897002e442b1 <http://www.w3.org/2005/sparql-results#solution> _:ub17bL6699C18 .
# _:ub17bL5473C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL5474C19 .
# _:ub17bL1545C18 <http://www.w3.org/2005/sparql-results#binding> _:ub17bL1546C19 .

# %% [markdown]
# Discover DBpedia information about any resources within 5km of Lancaster using a Federated query

# %%
%endpoint http://localhost:8890/sparql
# Out:
# Endpoint set to: http://localhost:8890/sparql

# %%
SELECT DISTINCT ?resource ?location
WHERE 
{ 
    SERVICE <http://dbpedia.org/sparql>
    {
        ?resource geo:geometry ?location ;
                  rdfs:label ?label . 
        FILTER( bif:st_intersects( ?location, bif:st_point(-2.78555560112, 54.010276794434), 5)) .
    }
}
LIMIT 1
# Out:
# {'head': {'link': [], 'vars': ['resource', 'location']},
#  'results': {'bindings': [{'location': {'datatype': 'http://www.openlinksw.com/schemas/virtrdf#Geometry',
#                                         'type': 'typed-literal',
#                                         'value': 'POINT(-2.7854299545288 '
#                                                  '54.009490966797)'},
#                            'resource': {'type': 'uri',
#                                         'value': 'http://dbpedia.org/resource/Furness_College,_Lancaster'}}],
#              'distinct': False,
#              'ordered': True}}

# %% [markdown]
# Explore Virtuoso geospatial reasoning capabilities and display output in N3 format

# %%
%format N3
# Out:
# Return format: N3

# %%
SELECT DISTINCT ?resource ?label ?long ?lat
WHERE 
{ 
    SERVICE <http://dbpedia.org/sparql>
    {
        ?resource geo:geometry ?location ;
                  rdfs:label ?label . 
        FILTER( bif:st_within( ?location, bif:st_geomfromtext("POLYGON((-2.980620861053467 54.10704331093268, -2.685363292694092 54.07563161821085, -2.708709239959717 53.979638627170516, -2.9559016227722164 54.00063080536647, -2.980620861053467 54.10704331093268 ))"))) .
        BIND(bif:st_x(?location) AS ?long) .
        BIND(bif:st_y(?location) AS ?lat) .
    }
}
LIMIT 1
# Out:
# {'head': {'link': [], 'vars': ['resource', 'label', 'long', 'lat']},
#  'results': {'bindings': [{'label': {'type': 'literal',
#                                      'value': 'Furness College, Lancaster',
#                                      'xml:lang': 'en'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                    'type': 'typed-literal',
#                                    'value': '54.0095'},
#                            'long': {'datatype': 'http://www.w3.org/2001/XMLSchema#double',
#                                     'type': 'typed-literal',
#                                     'value': '-2.78543'},
#                            'resource': {'type': 'uri',
#                                         'value': 'http://dbpedia.org/resource/Furness_College,_Lancaster'}}],
#              'distinct': False,
#              'ordered': True}}

# %% [markdown]
# Explore Virtuoso geospatial reasoning capabilities

# %%
PREFIX rt:<http://environment.data.gov.uk/flood-monitoring/def/core/>
PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
PREFIX geo:<http://www.w3.org/2003/01/geo/wgs84_pos#>

SELECT ?label ?town ?lon ?lat ?s 
FROM <http://environment.data.gov.uk/flood-monitoring/id/stations.rdf>
FROM <http://environment.data.gov.uk/flood-monitoring/id/measures.rdf>
FROM <http://environment.data.gov.uk/flood-monitoring/data/readings.rdf>
WHERE {
  ?s rt:town ?town ;
     geo:long ?lon ;
     geo:lat ?lat ; 
     rdfs:label ?label .
     FILTER( bif:st_intersects(bif:st_point(?lon, ?lat), bif:st_point(-2.78555560112, 54.010276794434), 10.0)) .
}
# Out:
# {'head': {'link': [], 'vars': ['label', 'town', 'lon', 'lat', 's']},
#  'results': {'bindings': [{'label': {'type': 'literal',
#                                      'value': 'Abbeystead Reservoir'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.978695'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.677098'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720101'},
#                            'town': {'type': 'literal', 'value': 'Abbeystead'}},
#                           {'label': {'type': 'literal', 'value': 'Scorton'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.943587'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.761388'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720102'},
#                            'town': {'type': 'literal', 'value': 'Scorton'}},
#                           {'label': {'type': 'literal', 'value': 'Six Arches'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.937868'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.770317'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/720120'},
#                            'town': {'type': 'literal', 'value': 'Scorton'}},
#                           {'label': {'type': 'literal', 'value': 'Caton'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.081344'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.722026'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724629'},
#                            'town': {'type': 'literal', 'value': 'Caton'}},
#                           {'label': {'type': 'literal', 'value': 'Burrow Beck'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.039446'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.780563'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724700'},
#                            'town': {'type': 'literal', 'value': 'Lancaster'}},
#                           {'label': {'type': 'literal',
#                                      'value': 'Lancaster Quay'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.051851'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.822021'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724735'},
#                            'town': {'type': 'literal', 'value': 'Lancaster'}},
#                           {'label': {'type': 'literal', 'value': 'Galgate'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '53.991743'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.792162'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/724836'},
#                            'town': {'type': 'literal', 'value': 'Galgate'}},
#                           {'label': {'type': 'literal', 'value': 'Heysham'},
#                            'lat': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '54.031798'},
#                            'lon': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#                                    'type': 'typed-literal',
#                                    'value': '-2.920253'},
#                            's': {'type': 'uri',
#                                  'value': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E73439-anglian'},
#                            'town': {'type': 'literal', 'value': 'Heysham'}}],
#              'distinct': False,
#              'ordered': True}}
